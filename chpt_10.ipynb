# %%
location_name = "Mount Everest"
country = 'Nepal'
description = """Mount Everest is the highest
peak in the world"""

print(f"Location:{location_name}")
# Out:
# Location:Mount Everest

# %%
location_full = location_name + ", " + country
